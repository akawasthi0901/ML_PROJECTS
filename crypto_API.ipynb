# %%
import requests
import csv
from requests.api import head

# %%
url = "http://api.coincap.io/v2/assets"

# %%
headers={
    'Accept':'application/json',
    'Content-Type':'application-json'
}

# %%
response=requests.request("GET", url,headers=headers,data={})
myjson=response.json()

# %%
print(myjson)
# Out:
# {'data': [{'id': 'bitcoin', 'rank': '1', 'symbol': 'BTC', 'name': 'Bitcoin', 'supply': '19140231.0000000000000000', 'maxSupply': '21000000.0000000000000000', 'marketCapUsd': '379201225390.5974762035197969', 'volumeUsd24Hr': '7357006035.0324756457784259', 'priceUsd': '19811.7371410301932199', 'changePercent24Hr': '-0.5660868127184990', 'vwap24Hr': '19872.6590004694910671', 'explorer': 'https://blockchain.info/'}, {'id': 'ethereum', 'rank': '2', 'symbol': 'ETH', 'name': 'Ethereum', 'supply': '122226307.6865000000000000', 'maxSupply': None, 'marketCapUsd': '190068717304.8143398871642324', 'volumeUsd24Hr': '4044038456.0763980469997393', 'priceUsd': '1555.0557069295122946', 'changePercent24Hr': '-1.6724791749162955', 'vwap24Hr': '1562.0809676849245347', 'explorer': 'https://etherscan.io/'}, {'id': 'tether', 'rank': '3', 'symbol': 'USDT', 'name': 'Tether', 'supply': '67550404112.7247100000000000', 'maxSupply': None, 'marketCapUsd': '67583486746.8514046514303840', 'volumeUsd24Hr': '11814493607.3895183105515907', 'priceUsd': '1.0004897473902819', 'changePercent24Hr': '-0.0154006548317114', 'vwap24Hr': '1.0007251396526338', 'explorer': 'https://www.omniexplorer.info/asset/31'}, {'id': 'usd-coin', 'rank': '4', 'symbol': 'USDC', 'name': 'USD Coin', 'supply': '51856656387.7963300000000000', 'maxSupply': None, 'marketCapUsd': '51890049789.5897870498741998', 'volumeUsd24Hr': '971582467.1535675032484944', 'priceUsd': '1.0006439559377630', 'changePercent24Hr': '-0.1164656365187003', 'vwap24Hr': '1.0002914720529262', 'explorer': 'https://etherscan.io/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'}, {'id': 'binance-coin', 'rank': '5', 'symbol': 'BNB', 'name': 'BNB', 'supply': '166801148.0000000000000000', 'maxSupply': '166801148.0000000000000000', 'marketCapUsd': '46261056714.8062695096864296', 'volumeUsd24Hr': '154979116.8838452120507465', 'priceUsd': '277.3425559085856502', 'changePercent24Hr': '0.1388493574786575', 'vwap24Hr': '276.5972026657916597', 'explorer': 'https://etherscan.io/token/0xB8c77482e45F1F44dE1745F52C74426C631bDD52'}, {'id': 'binance-usd', 'rank': '6', 'symbol': 'BUSD', 'name': 'Binance USD', 'supply': '19555493325.8092540000000000', 'maxSupply': None, 'marketCapUsd': '19564789748.5639897658942965', 'volumeUsd24Hr': '325086816.5565461689195300', 'priceUsd': '1.0004753867672807', 'changePercent24Hr': '-0.0140334899997502', 'vwap24Hr': '1.0004829142736888', 'explorer': 'https://etherscan.io/token/0x4Fabb145d64652a948d72533023f6E7A623C7C53'}, {'id': 'cardano', 'rank': '7', 'symbol': 'ADA', 'name': 'Cardano', 'supply': '34182044152.6290000000000000', 'maxSupply': '45000000000.0000000000000000', 'marketCapUsd': '16534876057.9287757658329098', 'volumeUsd24Hr': '283499918.0743209619042238', 'priceUsd': '0.4837298782980201', 'changePercent24Hr': '6.8123848027274093', 'vwap24Hr': '0.4697170917841071', 'explorer': 'https://cardanoexplorer.com/'}, {'id': 'xrp', 'rank': '8', 'symbol': 'XRP', 'name': 'XRP', 'supply': '45404028640.0000000000000000', 'maxSupply': '100000000000.0000000000000000', 'marketCapUsd': '14996453845.0892818575716800', 'volumeUsd24Hr': '201953370.5108053329035431', 'priceUsd': '0.3302890579158370', 'changePercent24Hr': '0.9928579062554854', 'vwap24Hr': '0.3295522179788305', 'explorer': 'https://xrpcharts.ripple.com/#/graph/'}, {'id': 'solana', 'rank': '9', 'symbol': 'SOL', 'name': 'Solana', 'supply': '349708816.3499124600000000', 'maxSupply': None, 'marketCapUsd': '10901181270.9617418671121363', 'volumeUsd24Hr': '58652030.8066095202951418', 'priceUsd': '31.1721659886727379', 'changePercent24Hr': '-0.0642736589975367', 'vwap24Hr': '31.1035457352436474', 'explorer': 'https://explorer.solana.com/'}, {'id': 'polkadot', 'rank': '10', 'symbol': 'DOT', 'name': 'Polkadot', 'supply': '1147731794.7831000000000000', 'maxSupply': None, 'marketCapUsd': '8348897278.4158129875102585', 'volumeUsd24Hr': '92525582.5609521301847980', 'priceUsd': '7.2742580769870539', 'changePercent24Hr': '-1.3632759564436068', 'vwap24Hr': '7.280772 ...

# %%
ourData = []
for x in myjson['data']:
    listing = [x['symbol'],x['name'],x['priceUsd']]
    ourData.append(listing)

# %%
print(ourData)
# Out:
# [['BTC', 'Bitcoin', '19811.7371410301932199'], ['ETH', 'Ethereum', '1555.0557069295122946'], ['USDT', 'Tether', '1.0004897473902819'], ['USDC', 'USD Coin', '1.0006439559377630'], ['BNB', 'BNB', '277.3425559085856502'], ['BUSD', 'Binance USD', '1.0004753867672807'], ['ADA', 'Cardano', '0.4837298782980201'], ['XRP', 'XRP', '0.3302890579158370'], ['SOL', 'Solana', '31.1721659886727379'], ['DOT', 'Polkadot', '7.2742580769870539'], ['DOGE', 'Dogecoin', '0.0625417432302085'], ['MATIC', 'Polygon', '0.8814947711688808'], ['DAI', 'Multi Collateral DAI', '1.0006012468889339'], ['SHIB', 'Shiba Inu', '0.0000123172066092'], ['LUNA', 'Terra', '1.8313419009353840'], ['TRX', 'TRON', '0.0630428109840322'], ['AVAX', 'Avalanche', '18.8828992520597550'], ['LEO', 'UNUS SED LEO', '5.2284061827344255'], ['WBTC', 'Wrapped Bitcoin', '19818.3782701442024508'], ['UNI', 'Uniswap', '6.3105069478249451'], ['ETC', 'Ethereum Classic', '32.4008906024556398'], ['LTC', 'Litecoin', '60.9864178322299860'], ['FTT', 'FTX Token', '26.1568649470633784'], ['LINK', 'Chainlink', '6.8218468490493841'], ['NEAR', 'NEAR Protocol', '4.1661366672267034'], ['ATOM', 'Cosmos', '12.5300435175633736'], ['CRO', 'Crypto.com Coin', '0.1190391028668381'], ['XMR', 'Monero', '153.8729665374775563'], ['XLM', 'Stellar', '0.1047037679394624'], ['BCH', 'Bitcoin Cash', '118.2025860490770740'], ['ALGO', 'Algorand', '0.3022641038554871'], ['BTCB', 'Bitcoin BEP2', '19796.9523491090695349'], ['FLOW', 'Flow', '1.9385046124065246'], ['FIL', 'Filecoin', '6.4138729162494107'], ['VET', 'VeChain', '0.0241589021915967'], ['ICP', 'Internet Computer', '6.4848629557235733'], ['EOS', 'EOS', '1.5231622230381234'], ['FRAX', 'Frax', '0.9971126812075740'], ['MANA', 'Decentraland', '0.7826476160810690'], ['XTZ', 'Tezos', '1.5113726804944410'], ['SAND', 'The Sandbox', '0.9273363257207953'], ['CHZ', 'Chiliz', '0.2157270690444941'], ['AXS', 'Axie Infinity', '15.1715552210666908'], ['AAVE', 'Aave', '86.9777335870897578'], ['EGLD', 'Elrond', '51.6688306831780804'], ['THETA', 'THETA', '1.1446901029257923'], ['QNT', 'Quant', '92.6050750997617494'], ['TUSD', 'TrueUSD', '1.0000574258941713'], ['BSV', 'Bitcoin SV', '52.6461303798422766'], ['ZEC', 'Zcash', '64.1693439429076160'], ['USDP', 'Pax Dollar', '1.0002567318701842'], ['OKB', 'OKB', '15.4978425191511341'], ['HBAR', 'Hedera Hashgraph', '0.0615814688102324'], ['KCS', 'KuCoin Token', '9.1509656535497388'], ['XEC', 'eCash', '0.0000443156994784'], ['MIOTA', 'IOTA', '0.2816550749378202'], ['MKR', 'Maker', '744.7226747916029125'], ['HT', 'Huobi Token', '4.7288254556331022'], ['GRT', 'The Graph', '0.1018116920031600'], ['KLAY', 'Klaytn', '0.2293232398023526'], ['SNX', 'Synthetix', '2.9279312624386400'], ['FTM', 'Fantom', '0.2685058738253498'], ['NEO', 'Neo', '9.1819963663554191'], ['LDO', 'Lido DAO', '2.0289007195064942'], ['RUNE', 'THORChain', '1.8880234533324875'], ['NEXO', 'Nexo', '1.0303219012251039'], ['HNT', 'Helium', '4.5341111916114532'], ['CRV', 'Curve DAO Token', '1.0718025721627905'], ['CAKE', 'PancakeSwap', '3.9837251232976268'], ['PAXG', 'PAX Gold', '1704.1235187811833727'], ['ENJ', 'Enjin Coin', '0.5183355899213125'], ['DASH', 'Dash', '46.7284818725064573'], ['BAT', 'Basic Attention Token', '0.3363181736056935'], ['WAVES', 'Waves', '4.5195097742753681'], ['STX', 'Stacks', '0.3592410103208912'], ['ZIL', 'Zilliqa', '0.0357089308148318'], ['LRC', 'Loopring', '0.3539187730468249'], ['MINA', 'Mina', '0.6572305352722169'], ['DCR', 'Decred', '30.0068738550122833'], ['KAVA', 'Kava', '1.6857499666140755'], ['KSM', 'Kusama', '48.7942437704267203'], ['BTG', 'Bitcoin Gold', '23.1076018723930068'], ['TWT', 'Trust Wallet Token', '0.9596382917997208'], ['1INCH', '1inch Network', '0.6849599707057796'], ['GNO', 'Gnosis', '154.2635778147104019'], ['XEM', 'NEM', '0.0435770194557974'], ['FEI', 'Fei Protocol', '0.9122774451491118'], ['CELO', 'Celo', '0.8286586580113706'], ['YFI', 'yearn.finance', '9725.6640364332878330'], ['HOT', 'Holo', '0.0020535438947618'], ['KNC', 'Kyber Netw ...

# %%
csvheader=['SYMBOL','NAME','PRICE(USD)']

# %%
with open('crypto.csv','w',encoding='UTF8',newline='') as f:
    writer = csv.writer(f)
    writer.writerow(csvheader)
    writer.writerows(ourData)
